# %%
# ======================================================
# Retail Intelligence Platform
# Notebook 05 - Power BI Data Model
# ======================================================

print("="*70)
print("Retail Intelligence Platform")
print("Notebook 05 - Power BI Data Model")
print("="*70)
# Out:
# ...
# Retail Intelligence Platform
# Notebook 05 - Power BI Data Model
# ...

# %%
# ======================================================
# Project Objective
# ======================================================

objectives = [

    "Design a Star Schema",

    "Create Fact and Dimension Tables",

    "Build Relationships",

    "Prepare Data for Power BI",

    "Create DAX Measures",

    "Develop Executive Dashboards"

]

for i, obj in enumerate(objectives, start=1):

    print(f"{i}. {obj}")
# Out:
# 1. Design a Star Schema
# 2. Create Fact and Dimension Tables
# 3. Build Relationships
# 4. Prepare Data for Power BI
# 5. Create DAX Measures
# 6. Develop Executive Dashboards

# %%
# ======================================================
# Star Schema
# ======================================================

print("""

                 Dim Date
                     |

Dim Customer --- Fact Sales --- Dim Product

                     |

                Dim Seller

                     |

               Dim Payment

""")
# Out:
#                  Dim Date
#                      |
#
# Dim Customer --- Fact Sales --- Dim Product
#
#                      |
#
#                 Dim Seller
#
#                      |
#
#                Dim Payment

# %%
# ======================================================
# Fact Table
# ======================================================

fact_tables = [

    "olist_order_items_dataset"

]

print("Fact Tables")

for table in fact_tables:

    print("-", table)
# Out:
# Fact Tables
# - olist_order_items_dataset

# %%
# ======================================================
# Dimension Tables
# ======================================================

dimension_tables = [

    "olist_customers_dataset",

    "olist_products_dataset",

    "olist_orders_dataset",

    "olist_sellers_dataset",

    "olist_order_payments_dataset",

    "product_category_name_translation"

]

print("Dimension Tables")

for table in dimension_tables:

    print("-", table)
# Out:
# Dimension Tables
# - olist_customers_dataset
# - olist_products_dataset
# - olist_orders_dataset
# - olist_sellers_dataset
# - olist_order_payments_dataset
# - product_category_name_translation

# %%
# ======================================================
# Relationships
# ======================================================

relationships = [

("customer_id","olist_customers_dataset","olist_orders_dataset"),

("order_id","olist_orders_dataset","olist_order_items_dataset"),

("order_id","olist_orders_dataset","olist_order_payments_dataset"),

("seller_id","olist_sellers_dataset","olist_order_items_dataset"),

("product_id","olist_products_dataset","olist_order_items_dataset"),

("product_category_name",

"olist_products_dataset",

"product_category_name_translation")

]

for left,right1,right2 in relationships:

    print(f"{left:<25}{right1}  --->  {right2}")
# Out:
# customer_id              olist_customers_dataset  --->  olist_orders_dataset
# order_id                 olist_orders_dataset  --->  olist_order_items_dataset
# order_id                 olist_orders_dataset  --->  olist_order_payments_dataset
# seller_id                olist_sellers_dataset  --->  olist_order_items_dataset
# product_id               olist_products_dataset  --->  olist_order_items_dataset
# product_category_name    olist_products_dataset  --->  product_category_name_translation

# %%
# ======================================================
# Cardinality
# ======================================================

cardinality = [

("Customers","Orders","1:*"),

("Orders","Order Items","1:*"),

("Orders","Payments","1:*"),

("Products","Order Items","1:*"),

("Sellers","Order Items","1:*")

]

for row in cardinality:

    print(row)
# Out:
# ('Customers', 'Orders', '1:*')
# ('Orders', 'Order Items', '1:*')
# ('Orders', 'Payments', '1:*')
# ('Products', 'Order Items', '1:*')
# ('Sellers', 'Order Items', '1:*')

# %%
# ======================================================
# Cross Filter Direction
# ======================================================

print("""

Recommended:

Single Direction

Dimension  ----->  Fact

Avoid:

Both Direction

unless absolutely necessary.

""")
# Out:
# Recommended:
#
# Single Direction
#
# Dimension  ----->  Fact
#
# Avoid:
#
# Both Direction
#
# unless absolutely necessary.

# %%
# ======================================================
# Power BI Assets
# ======================================================

folders = [

"Data",

"Power Query",

"Data Model",

"DAX",

"Reports",

"Dashboard"

]

for folder in folders:

    print(folder)
# Out:
# Data
# Power Query
# Data Model
# DAX
# Reports
# Dashboard

# %%
# ======================================================
# Summary
# ======================================================

print("="*70)

print("Power BI Data Model Planned Successfully")

print("="*70)

print("Next Module : Power Query")

print("="*70)
# Out:
# ...
# Power BI Data Model Planned Successfully
# ...
# Next Module : Power Query
# ...

# %%
# ======================================================
# Power Query Workflow
# ======================================================

steps = [

    "Load CSV Files",

    "Check Data Types",

    "Remove Errors",

    "Handle Missing Values",

    "Rename Columns",

    "Merge Queries",

    "Append Queries",

    "Remove Duplicates",

    "Create Date Table",

    "Load to Data Model"

]

for i, step in enumerate(steps, start=1):

    print(f"{i}. {step}")
# Out:
# 1. Load CSV Files
# 2. Check Data Types
# 3. Remove Errors
# 4. Handle Missing Values
# 5. Rename Columns
# 6. Merge Queries
# 7. Append Queries
# 8. Remove Duplicates
# 9. Create Date Table
# 10. Load to Data Model

# %%
# ======================================================
# Data Type Validation
# ======================================================

tables = [

    "Customers",

    "Orders",

    "Order Items",

    "Payments",

    "Products",

    "Sellers"

]

recommended = [

    "Text",

    "Date/Time",

    "Decimal",

    "Decimal",

    "Text",

    "Text"

]

import pandas as pd

datatype_df = pd.DataFrame({

    "Table": tables,

    "Recommended Type": recommended

})

display(datatype_df)
# Out:
#          Table Recommended Type
# 0    Customers             Text
# 1       Orders        Date/Time
# 2  Order Items          Decimal
# 3     Payments          Decimal
# 4     Products             Text
# 5      Sellers             Text

# %%
# ======================================================
# Transformations
# ======================================================

transformations = [

    "Trim",

    "Clean",

    "Replace Values",

    "Remove Nulls",

    "Remove Duplicates",

    "Split Columns",

    "Merge Queries",

    "Append Queries",

    "Change Data Types",

    "Create Custom Columns"

]

for t in transformations:

    print("•", t)
# Out:
# • Trim
# • Clean
# • Replace Values
# • Remove Nulls
# • Remove Duplicates
# • Split Columns
# • Merge Queries
# • Append Queries
# • Change Data Types
# • Create Custom Columns

# %%
# ======================================================
# Merge Strategy
# ======================================================

relationships = [

    ("Customers","Orders","customer_id"),

    ("Orders","Order Items","order_id"),

    ("Orders","Payments","order_id"),

    ("Products","Order Items","product_id"),

    ("Sellers","Order Items","seller_id")

]

for left,right,key in relationships:

    print(f"{left:<15} --> {right:<15} Key : {key}")
# Out:
# Customers       --> Orders          Key : customer_id
# Orders          --> Order Items     Key : order_id
# Orders          --> Payments        Key : order_id
# Products        --> Order Items     Key : product_id
# Sellers         --> Order Items     Key : seller_id

# %%
# ======================================================
# Best Practices
# ======================================================

best_practices = [

    "Keep one fact table",

    "Create dimension tables",

    "Disable unnecessary load",

    "Use reference instead of duplicate",

    "Remove unused columns",

    "Rename queries clearly",

    "Use proper data types",

    "Avoid many-to-many relationships",

    "Create a Date table",

    "Apply transformations before loading"

]

for i, practice in enumerate(best_practices, start=1):

    print(f"{i}. {practice}")
# Out:
# 1. Keep one fact table
# 2. Create dimension tables
# 3. Disable unnecessary load
# 4. Use reference instead of duplicate
# 5. Remove unused columns
# 6. Rename queries clearly
# 7. Use proper data types
# 8. Avoid many-to-many relationships
# 9. Create a Date table
# 10. Apply transformations before loading

# %%
# ======================================================
# Load Strategy
# ======================================================

print("""

Raw CSV

     ↓

Power Query

     ↓

Transform

     ↓

Dimension Tables

     ↓

Fact Table

     ↓

Relationships

     ↓

DAX Measures

     ↓

Reports

     ↓

Dashboard

""")
# Out:
# Raw CSV
#
#      ↓
#
# Power Query
#
#      ↓
#
# Transform
#
#      ↓
#
# Dimension Tables
#
#      ↓
#
# Fact Table
#
#      ↓
#
# Relationships
#
#      ↓
#
# DAX Measures
#
#      ↓
#
# Reports
#
#      ↓
#
# Dashboard

# %%
# ======================================================
# Validation Checklist
# ======================================================

checklist = [

    "No duplicate keys",

    "Correct relationships",

    "Correct data types",

    "No unnecessary columns",

    "No hidden errors",

    "Star schema created",

    "Date table available",

    "Measures separated from columns"

]

for item in checklist:

    print("[ ]", item)
# Out:
# [ ] No duplicate keys
# [ ] Correct relationships
# [ ] Correct data types
# [ ] No unnecessary columns
# [ ] No hidden errors
# [ ] Star schema created
# [ ] Date table available
# [ ] Measures separated from columns

# %%
# ======================================================
# Module Summary
# ======================================================

print("="*70)

print("POWER QUERY MODULE COMPLETED")

print("="*70)

print("Next Module : DAX Measures")

print("="*70)
# Out:
# ...
# POWER QUERY MODULE COMPLETED
# ...
# Next Module : DAX Measures
# ...
